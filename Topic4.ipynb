# %% [markdown]
# # Topic 4: Poisson Process Simulation
# ## 1: Homogenous Poisson Process

# %%
import numpy as np
from scipy.stats import expon

# %% [markdown]
# (1) Implement the algorithm from the previous section. Return N(T) as integer, and S1,...SN(T) as an numpy array.

# %%
# implement poisson process algorithm
def poisson_process(lmbda, T):
    N = 0
    S = []
    t = 0
    dt = expon.rvs(scale=1 / lmbda)
    while (t + dt < T):
        t += dt
        N += 1
        S += [t]
        dt = expon.rvs(scale=1 / lmbda)
    return N, np.array(S)

# %% [markdown]
# (2) Write a function that takes as inputs: T, S1, ...SN(T) and t"< T and return the value of the poisson process at time t. Raise an exception if the user requests t > T.

# %%
# implement function to evaluate poisson process
# at t given T and  arrival times
def evaluate_process(T, S, t):
    if t <= T:
        return np.sum(S <= t)
    else:
        raise Exception('t > T')

# %% [markdown]
# (3) Generate 10000 simulations with λ=1.5 and T=5.Calculate the means and covariance the covariance matrix of N(1) - N(0), N(2) - N(1), N(3) - N(2), N(4) - N(3), N(5) - N(4) etc

# %%
# generate 10000 simulations, calculate means
# and covariances of N(1) - N(0), N(2) - N(1), etc
lmbda = 1.5
T = 5
nsims = 10000
t_vals = [0,1,2,3,4,5]
Nt = np.zeros((nsims, len(t_vals)))
for i in range(0, nsims):
    N, S = poisson_process(lmbda, T)
    for j, t in enumerate(t_vals):
        Nt[i,j] = evaluate_process(T, S, t)
Nt_diff = Nt[:,1:] - Nt[:,:-1]
print('Poisson process means: ', np.mean(Nt_diff, axis=0))
print('Poisson process covariance: ', np.cov(Nt_diff, rowvar=False))
# Out:
# Poisson process means:  [1.5022 1.499  1.5046 1.5139 1.4912]
# Poisson process covariance:  [[ 1.52314747  0.03060526 -0.00831095  0.01322074 -0.0045811 ]
#  [ 0.03060526  1.50114911 -0.01159656 -0.0170378  -0.0170105 ]
#  [-0.00831095 -0.01159656  1.51953079 -0.01591553 -0.02306183]
#  [ 0.01322074 -0.0170378  -0.01591553  1.50635743  0.00517284]
#  [-0.0045811  -0.0170105  -0.02306183  0.00517284  1.46986955]]

# %% [markdown]
# Implement the algorithm from the previous section so that it returns N(T) and numpy array S given lambda and T
#
# Copy your evaluation function from the previous section over to this notebook
#
# Generate 10000 simulations. For k = 6, 7, 8, 9; plot the empirical pmf of N(t) | N(T) = k for t = 1, 4. Draw a line graph of the theoretical pmf of the corresponding binomial distribution.

# %%
import numpy as np 
import matplotlib.pyplot as plt
from scipy.stats import poisson, uniform, binom

# %%
# generate poisson process
def poisson_process(lmbda, T):
    N = poisson.rvs(lmbda*T)
    S = uniform.rvs(size=N) * T
    return N, np.sort(S)

# %%
def evaluate_process(T, S, t):
    if t <= T:
        return np.sum(S <= t)
    else:
        raise Exception('t > T')

# %%
# generate 10000 runs of poisson process
lmbda = 1.5
T = 5
nsims = 10000
t_vals = [1, 4]
Nt = np.zeros((nsims, len(t_vals)))
Ns = np.zeros(nsims)
for i in range(0, nsims):
    N, S = poisson_process(lmbda, T)
    Ns[i] = N
    for j, t in enumerate(t_vals):
        Nt[i,j] = evaluate_process(T, S, t)

# %%
#plot conditional distributions from simulations
k_vals = [6,7,8,9]
fig, ax = plt.subplots(nrows=4, ncols=2, figsize=(10,10))
for i, k in enumerate(k_vals):
    for j, t in enumerate(t_vals):
        loc_k = (Ns==k)
        Nt_temp = Nt[loc_k,j]
        vals, count = np.unique(Nt_temp, return_counts=True)
        ax[i,j].bar(vals, count/len(Nt_temp))
        x_vals = np.arange(0, k+1)
        theo_vals = binom.pmf(x_vals,  n=k, p = t/T)
        ax[i,j].plot(x_vals, theo_vals)

# %% [markdown]
# ## 2: Nonhomogeneous Poisson Process

# %% [markdown]
# ## Thining Method
#
# Implement the thinning Method for a non-homogeneous poisson process, given a function λ(t) with maximum value λmax.
#
# Generate 10,000 paths from a nonhomogeneous poisson process with intensity lambda(t)=−(t−1)^2+2 for 0≤t≤2. Use scipy.optimize.minimize_scalar to find the maximum of this function.
#
# Over the grid t = [.01, .02, ..., 1.0], plot mean number of events that have occured by that time over the set of paths. Compare to to the theoretical integral of λ(t), −t^3/3+t^2+t

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import minimize_scalar
from scipy.stats import poisson, uniform

def poisson_process(lmbda, T):
    N = poisson.rvs(lmbda*T)
    S = uniform.rvs(size=N) * T
    return np.sort(S)

def thinning(lmbda, lmbda_max, T):
    ts = poisson_process(lmbda_max, T)
    S = []
    for t in ts:
        p = lmbda(t) / lmbda_max
        if uniform.rvs() < p:
            S.append(t)
    return np.array(S)

# %%
def lmbda(t):
    return -(t-1)**2 + 2

def neg_lmbda(t):
    return -1*lmbda(t)

T = 2

sol = minimize_scalar(neg_lmbda, bounds=(0,T))
lmbda_max = lmbda(sol.x)

n = 10_000

S=[]

for i in range(0, n):
    S.append(thinning(lmbda, lmbda_max, T))

# %%
S
# Out:
# [array([0.34300914, 0.36716225, 1.14814991, 1.3385806 , 1.93529639]),
#  array([0.79863259, 1.21850425, 1.69920219, 1.75110461]),
#  array([0.75680836, 1.38800564]),
#  array([1.6006706]),
#  array([1.75645632]),
#  array([0.31461582, 0.31940497, 0.65277411, 0.82294544, 1.00356685,
#         1.57749228, 1.69658684, 1.78284019, 1.98486087]),
#  array([1.49943368, 1.60608452]),
#  array([0.02335317, 0.44289855, 1.02027236]),
#  array([0.49406328, 1.27432213, 1.94210109]),
#  array([0.01094654, 0.11997576, 1.28774016, 1.58582714]),
#  array([0.06603142, 0.32148491, 0.87262407, 1.11740393, 1.46827181,
#         1.62160196]),
#  array([0.11210703, 0.5242396 , 1.01347665, 1.27506796, 1.66863128]),
#  array([0.01859042, 0.46028622, 0.58985504, 1.52904438]),
#  array([0.6793865 , 0.86129855, 1.03140746, 1.40258717, 1.81262275]),
#  array([0.32441902, 0.4442172 , 0.86664877, 1.22965292, 1.47607843,
#         1.77375081]),
#  array([0.17139396, 0.2204528 , 1.28957744, 1.35987834]),
#  array([0.79072193, 0.84229665, 1.23161898, 1.39219941, 1.47527389]),
#  array([0.27150199]),
#  array([0.15836362, 0.41622988, 0.54812876, 1.35464006, 1.54627381,
#         1.59471737]),
#  array([0.33114276, 0.37339551, 1.28437697, 1.54307573, 1.59754074]),
#  array([0.78415156, 1.02433066]),
#  array([0.21793665, 0.67887315, 0.91365836]),
#  array([1.56827884]),
#  array([0.01793899, 0.07113783, 1.18871773]),
#  array([0.35640299, 0.63713467, 0.75550127, 1.48622112, 1.6106215 ,
#         1.8226274 , 1.84193185]),
#  array([1.62343686, 1.74653044, 1.82306416]),
#  array([0.98912987, 1.04497613, 1.0570512 , 1.48968227]),
#  array([1.16759454, 1.97185802]),
#  array([0.83674133, 1.91457022]),
#  array([1.42771744]),
#  array([0.8938707 , 0.93075782, 1.32149922, 1.43938669, 1.45517093,
#         1.64650846]),
#  array([0.62074774]),
#  array([0.39277623, 1.52015106]),
#  array([0.50589228, 0.76369933]),
#  array([0.34765882, 1.9913612 ]),
#  array([0.37691459, 0.69584558]),
#  array([0.15434432, 1.27931618, 1.52926349]),
#  array([0.35693648, 0.43612039, 1.13149603, 1.35777359, 1.66871901]),
#  array([0.34186062, 1.2636633 ]),
#  array([0.05418447, 0.43480519, 1.2980025 , 1.8825783 ]),
#  array([0.83164889]),
#  array([0.33722032, 0.75029016, 1.43288539, 1.62799342]),
#  array([0.47636783, 0.51445362, 0.6571358 , 1.19560948, 1.52901173]),
#  array([0.75872115, 1.04607156, 1.45565063]),
#  array([0.17026298, 0.77237982, 0.88304574, 0.91703989, 1.04326043]),
#  array([0.938244  , 0.94810057, 0.99797906, 1.93596178]),
#  array([0.20025021, 1.50024316]),
#  array([0.18530356, 0.31602295, 0.53074662]),
#  array([1.16180336]),
#  array([0.84983704, 1.0056193 , 1.35756015]),
#  array([0.18371774, 0.74481302, 1.40272146]),
#  array([0.73714557, 0.82147389, 1.5783183 , 1.77119457]),
#  array([0.6587581 , 0.78467524, 0.92102498, 1.46448801, 1.52304567]),
#  array([0.53328911, 0.71967458, 0.75219069]),
#  array([0.3684319 , 1.57696739, 1.84129972, 1.96073912, 1.99748252]),
#  array([1.49252115]),
#  array([0.01484698, 0.39662214, 0.55667966, 0.66591323, 0.73193475,
#         0.76006481, 0.82081718, 0.94672919, 1.1309419 , 1.49751442,
#         1.54926834]),
#  array([0.91893649, 1.57843727, 1.71239351]),
#  array([0.29297113, 0.96749348, 1.09298626, 1.27219817]),
#  array([0.09989655, 0.39844958]),
#  array([0.22771073, 0.24073889, 0.49821573, 1.13343853]),
#  array([0.238872  , 0.62574641, 0.7406093 , 0.78032487, 1.91436766]),
#  array([0.12183469, 1.75713186, 1.9974025 ]),
#  array([0.86686217]),
#  array([0.89034572, 1.86068781]),
#  array([1.83693348]),
#  array([0.07037891, 0.22845769, 0.37437134, 0.59168172, 0.99771285,
#         1.26157947]),
#  array([0.13763483, 0.80088852, 1.05373199, 1.06361465, 1.09614905,
#         1.12022638, 1.36212477]),
#  array([0.36412625, 1.00315251]),
#  array([0.66413464, 1.6402345 ]),
#  array([], dtype=float64),
#  array([0.56738254, 1.50086394, 1.50474817, 1.57703368, 1.66057968,
#         1.7250519 ]),
#  array([0.42634176, 0.90825002, 1.20547265]),
#  array([0.24754451, 0.38933337, 1.06244588, 1.1838912 , 1.22790818,
#  array([1.05892654, 1.4074863 , 1.57863767]),
#  array([0.99701875, 1.73984005]),
#  array([0.3510376 , 0.84381328, 1.096637  , 1.2752406 , 1.46525217,
#         1.47193326]),
#  array([0.28376239, 1.19451452, 1.4502246 ]),
#  array([0.6400493 , 1.22301211]),
#  array([0.00478471, 0.15485695]),
#  array([0.3241935 , 0.42105652, 1.97243788]),
#  array([0.490728  , 0.94756791, 1.59180717]),
#  array([1.75303988, 1.76213137]),
#  array([0.91341586, 1.13183621, 1.68276066]),
#  array([1.18189991, 1.36918425, 1.50737731]),
#  array([0.14719961, 1.92124113]),
#  array([0.80085811, 1.01522325, 1.38416591, 1.4596248 , 1.81738076]),
#  array([0.18581122, 0.44848063, 1.75454758]),
#  array([0.27791171, 1.89047042]),
#  array([0.81361614, 1.18977243, 1.39152401, 1.70132569]),
#  array([0.33914437, 1.36236072, 1.79107027, 1.92479865]),
#  array([0.6336248]),
#  array([0.2007291 , 0.31460662, 0.95665155, 1.06766429, 1.22684906]),
#  array([0.27259637, 1.34978601, 1.76451343]),
#  array([0.83660955, 1.29588637]),
#  array([0.44132257, 0.6940819 , 1.15557437, 1.54119699, 1.76620683]),
#  array([0.50573968, 0.62196403]),
#  array([0.46711372, 1.75914972, 1.78694404]),
#  array([1.03376781, 1.78352312]),
#  array([0.33943393, 1.01884012, 1.44290087]),
#  array([0.07680116, 0.64332946, 0.81301045, 1.62995906]),
#  array([0.45712545, 0.87862318]),
#  array([1.34975311, 1.83908869, 1.95772451]),
#  array([0.35381034, 0.53026476, 1.33638555]),
#  array([1.57474764]),
#  array([0.04459501, 0.28344674, 0.3432405 , 1.25703303, 1.421461  ,
#         1.7540023 ]),
#  array([0.55979621, 1.29733359]),
#  array([1.77766862, 1.9210672 ]),
#  array([0.97937327]),
#  array([0.45840071, 0.84428433, 1.58185048]),
#  array([0.36924272, 1.23839523, 1.71741861]),
#  array([1.44871022, 1.63023078, 1.75454952]),
#  array([0.92074007]),
#  array([0.65761001, 1.2880036 ]),
#  array([1.41145603, 1.69151343, 1.78807944]),
#  array([0.35496766]),
#  array([0.12063119, 1.12228727]),
#  array([1.15041088, 1.36858421, 1.87049016]),
#  array([0.83893763, 0.98617287, 1.469146  ]),
#  array([0.09864162, 0.24170855, 1.02537132, 1.89341861]),
#  array([0.62146907, 0.81641614, 0.96587865, 1.200518  ]),
#  array([0.17323504, 0.44411368, 0.86313442, 1.48501037]),
#  array([0.41843709, 0.88001135]),
#  array([0.36536907, 0.96225906, 1.10687506, 1.25734233]),
#  array([0.44960256, 0.96431912, 1.54232537]),
#  array([0.6314244 , 0.69405299, 1.85067779]),
#  array([0.89049583, 1.00624134, 1.39258282, 1.65247143, 1.67025881]),
#  array([0.09476197, 0.98183933, 1.02898165, 1.06273922, 1.4021345 ,
#         1.66635141]),
#  array([0.35419651, 0.49477153]),
#  array([1.42169763]),
#  array([0.08149435, 0.42539312, 1.09280475, 1.77282136, 1.88245942]),
#  array([1.21438532, 1.2224991 , 1.40038074, 1.61897021, 1.94055725]),
#  array([1.18602249, 1.25857059, 1.51151557]),
#  array([0.64759722, 0.77488747, 1.34174489, 1.83440954, 1.85315749]),
#  array([0.21292018, 0.40160934, 0.73641282, 1.41717229]),
#  array([0.48154005, 1.68362934]),
#  array([1.28090089, 1.38933751]),
#  array([0.04065703, 1.13872786]),
#  array([0.95769334, 1.08989824, 1.27911836, 1.3334966 ]),
#  array([1.35812805e-03, 1.00562696e+00, 1.07392716e+00, 1.66386689e+00]),
#  array([1.16829678]),
#  array([0.04009185, 0.46967673, 0.47116984, 1.03089361]),
#  array([0.95105092, 1.30707237, 1.52606785, 1.73563457]),
#  array([0.06040589, 0.32571223, 0.55066226]),
#  array([1.08669506]),
#  array([1.42086803]),
#  array([0.76687571, 1.43158938]),
#  array([0.07822244, 0.3869464 , 0.4805321 , 0.54288636, 0.89351147,
#         1.8097377 ]),
#  array([0.16142747, 0.37474594, 0.47991609, 1.72495467]),
#  array([0.92081826, 1.66317543]),
#  array([0.28857645, 0.36836242, 1.02442532]),
#  array([0.04904834, 0.08563162, 0.92620295, 1.14618671]),
#  array([0.18157298, 0.37702766, 0.88924952, 0.97459277, 1.64524328]),
#  array([0.43169232, 0.89353308, 1.43289973]),
#  array([0.3717507 , 0.90773603]),
#  array([0.33131828, 0.58594141, 0.94052018, 1.80972545, 1.93111656]),
#  array([0.76923852, 1.21074242, 1.58353551, 1.66280989]),
#  array([0.08108121, 1.41841066, 1.68810374]),
#  array([0.11556683, 0.33561385, 1.49401198, 1.69022899, 1.88453785]),
#  array([0.37447102, 0.66526721, 0.96260198, 1.01686515, 1.19073704,
#         1.27105338, 1.47424248, 1.98814464]),
#  array([1.10509313, 1.51139515, 1.60295696]),
#  array([], dtype=float64),
#  array([0.41294696, 1.23937809]),
#  array([0.92092081, 1.37819396, 1.50985317, 1.55263359]),
#  array([0.45096687]),
#  array([0.50666125, 0.70643644, 0.72830569, 1.22202771, 1.32358326]),
#  array([0.15700365, 0.36438389, 0.93275128, 1.74421362]),
#  array([], dtype=float64),
#  array([0.3975701 , 0.55764061, 1.45019966, 1.97252371]),
#  array([0.11858685, 0.84415499, 1.46450629, 1.71117367]),
#  array([0.78024142]),
#  array([0.2072376 , 0.51115522, 0.98336279, 0.99776827, 1.27401911,
#         1.4417983 ]),
#  array([1.12387513, 1.25355562]),
#  array([1.24505997, 1.95831956]),
#  array([0.31021359, 0.86917656, 1.03775714, 1.23263259]),
#  array([0.97432388, 1.45456456]),
#  array([0.38394084, 1.30217169, 1.30354743]),
#  array([0.47181894, 1.09696821]),
#  array([0.53140849, 1.64896473]),
#  array([], dtype=float64),
#  array([0.79776431, 1.22755704, 1.30617174]),
#  array([0.02955229, 0.8289369 , 1.4416266 ]),
#  array([1.24471064, 1.3946462 , 1.56291035, 1.73113326]),
#  array([0.54097073]),
#  array([0.30363567, 0.33140142, 0.96436067, 1.33416746]),
#  array([0.79001983, 0.98057301, 1.57118093]),
#  array([0.00247386, 0.24719899, 0.79846481, 1.8172957 , 1.94526763]),
#  array([1.3043003 , 1.32510905, 1.93170919]),
#  array([0.54556199, 0.81974384, 1.75189383]),
#  array([0.47334885, 0.52141752, 0.72584432, 0.76594046, 1.00056662,
#         1.01873139, 1.37691891]),
#  array([0.77864595, 0.9232496 ]),
#  array([0.12328461, 1.56600845]),
#  array([1.26552406, 1.50409463, 1.54859452]),
#  array([0.02015198, 0.18106352]),
#  array([0.21820064, 1.32028906]),
#  array([0.38430664, 0.7065307 , 1.36007149, 1.94308583]),
#  array([0.56749277, 1.37528478, 1.59404112, 1.6026191 ]),
#  array([], dtype=float64),
#  array([0.64548454, 1.34115022, 1.85025052, 1.85279558]),
#  array([1.44220502, 1.50027125]),
#  array([1.19942444]),
#  array([0.15952128, 0.20553955, 0.50737707, 0.53833173, 0.58471662,
#         0.67970137, 0.93251768, 1.25783773, 1.35364916]),
#  array([0.57520862, 1.22346422, 1.77817943]),
#  array([0.8230793]),
#  array([0.38755561, 1.7169797 ]),
#  array([0.25366948, 1.12487891, 1.77509857]),
#  array([0.1012518 , 0.16445964, 0.39135343, 1.42155841, 1.94128966,
#         1.94838356]),
#  array([0.2141589 , 0.67257083, 0.84647567, 0.92605675, 1.4194922 ,
#         1.44824972, 1.58925955, 1.86179981]),
#  array([1.02346785, 1.83731382]),
#  array([1.03142308, 1.98776341]),
#  array([1.35051407, 1.91325113]),
#  array([0.85946427, 0.96617663, 1.02522893, 1.13666613, 1.18681117,
#         1.8000007 ]),
#  array([0.76999448, 0.78638107, 0.94622629, 1.13976554]),
#  array([0.88912432, 1.48424311, 1.72412551]),
#  array([0.58722617, 0.60439497, 0.76162193, 1.36643102]),
#  array([0.95112612, 1.2116877 , 1.41897027]),
#  array([0.98699452]),
#  array([0.28543305, 0.87629047]),
#  array([0.56805363]),
#  array([1.35571082, 1.64315485, 1.98044702]),
#  array([0.10978205, 0.74853429]),
#  array([0.07481882, 0.97777403, 1.58313563]),
#  array([0.38893536, 0.54794314, 0.75163285, 0.90885558, 0.9305429 ,
#         1.70737544]),
#  array([0.43081765, 1.02681379, 1.03093078, 1.05082562, 1.78422255,
#         1.92542956]),
#  array([1.07076568, 1.58437381, 1.99725032]),
#  array([0.86681102]),
#  array([0.00641324, 0.65930884, 1.72588451, 1.75820596]),
#  array([0.46633333, 0.50324456, 0.68038672]),
#  array([0.40901245, 1.44005268, 1.6747641 , 1.97334782]),
#  array([0.07981524, 1.181058  , 1.74406917]),
#  array([0.24683345, 0.32449944, 0.53133935, 0.62621139, 0.70467195,
#         0.70542584]),
#  array([1.45291698]),
#  array([0.08321676, 0.15559639, 0.9791822 , 1.30041846, 1.62226446,
#         1.77719935]),
#  array([0.58180114, 1.29058725, 1.52708549]),
#  array([0.89985221, 1.02802938, 1.15338505, 1.19299164, 1.32520416]),
#  array([1.1705559 , 1.41996855, 1.43242933]),
#  array([0.24391611, 1.5109635 , 1.56545703, 1.56887363]),
#  array([0.16741188, 0.34668631, 0.67889598, 1.02873124]),
#  array([1.22282667, 1.81093763, 1.81939064]),
#  array([0.70658867, 1.31840233, 1.57279829, 1.72596557]),
#  array([1.35131934, 1.47860379, 1.62990925]),
#  array([0.08525238, 0.10954465, 0.18278243, 0.70924616, 1.86491153]),
#  array([1.2852417 , 1.30782253, 1.47632052]),
#  array([0.2593918 , 0.318978  , 0.7992984 , 0.80059841, 1.46490513]),
#  array([0.70001765]),
#  array([0.40926366, 0.49207784, 0.71994804, 1.32182088]),
#  array([0.14523506, 0.59164837, 0.84639899, 1.42398128]),
#  array([0.00714846, 0.98682412, 1.10022616, 1.76809655]),
#  array([0.19678978, 0.69125089, 0.81145092, 1.11050751, 1.11984253]),
#  array([0.40995363, 0.60769452, 0.65233159, 1.60520518, 1.76827187]),
#  array([0.2684955 , 0.97552267, 1.31959653]),
#  array([0.90592264, 1.00863853, 1.34088871]),
#  array([0.00109312, 0.22820928, 0.66463751]),
#  array([0.14224675, 0.45707013, 0.64340464, 0.76470849, 1.19564413,
#         1.67413436]),
#  array([0.38061554, 0.97302537, 1.03672019, 1.38861971, 1.50142199]),
#  array([1.2037349 , 1.36291038, 1.54496127, 1.75221661, 1.85982478]),
#  array([], dtype=float64),
#  array([0.67993194, 0.82158689]),
#  array([0.78613108, 1.04261578, 1.31373841, 1.3328468 ]),
#  array([1.70103209]),
#  array([0.07391689, 0.09033213, 0.39728296]),
#  array([0.64887963]),
#  array([0.29448008, 0.8268096 , 0.97879413, 1.31645762]),
#  array([0.34181356, 1.85687734]),
#  array([1.22087923, 1.74383325]),
#  array([0.15392505, 0.90353259, 1.12148785, 1.34477303]),
#  array([0.15637355, 0.24224556, 0.71433611, 1.12897216]),
#  array([0.79022037, 1.12883505, 1.14906844]),
#  array([0.89727984, 1.86127892]),
#  array([0.95051026, 1.61936839]),
#  array([0.49231972, 1.65525516]),
#  array([1.12112654, 1.1261679 , 1.27841873, 1.77825953]),
#  array([0.49968775, 0.80790399, 1.2377263 , 1.81110369]),
#  array([0.30277612, 0.83639787, 1.79370575, 1.99876074]),
#  array([0.21766428, 0.36897032, 0.89522071, 1.20114643, 1.47628233,
#         1.50817564, 1.78820163]),
#  array([1.01568575, 1.63114587]),
#  array([0.54432779, 0.68193403, 0.88094366, 1.44717873]),
#  array([0.35629456, 0.52173398, 0.70125999, 0.72439902]),
#  array([0.72111078, 1.88052949]),
#  array([0.30614353, 0.58971998]),
#  array([1.90927868]),
#  array([0.39147107, 0.45888419, 0.73633031, 0.88828228]),
#  array([0.70963182, 1.02047904, 1.14959219, 1.96868298]),
#  array([0.18802327, 0.3817901 , 1.66388741]),
#  array([0.04092525, 1.53478214]),
#  array([0.73427595, 0.85989758, 1.7430013 ]),
#  array([0.17596374, 1.53223288]),
#  array([0.26389694, 0.41681416, 1.79148119]),
#  array([0.39581649, 0.58765255, 0.83585153, 0.86689897, 1.34696213,
#         1.97552496]),
#  array([0.98674439, 1.08214473]),
#  array([], dtype=float64),
#  array([0.13495505, 0.1427856 , 0.35213671, 0.35854732, 0.43608724,
#         1.08362812, 1.57816723, 1.63372149]),
#  array([0.58977605, 0.59487007, 0.60409581, 1.51157852, 1.58382287]),
#  array([0.13298056]),
#  array([0.88277209, 1.88204297]),
#  array([1.0501736 , 1.53316318]),
#  array([0.46800357, 0.59509818, 0.9749799 , 1.5194469 , 1.59556167]),

#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([0.99706267, 1.01424093, 1.77580545]),
#  array([0.20304547, 1.43652806]),
#  array([1.10915483]),
#  array([0.43884354, 0.86957092, 0.98425495]),
#  array([1.11415413, 1.48297587, 1.93599778]),
#  array([0.94465553]),
#  array([0.21750374, 0.54498655, 0.62866169, 0.72452347, 0.88539188]),
#  array([0.04481971, 1.15256252, 1.86426403]),
#  array([], dtype=float64),
#  array([1.11852054]),
#  array([0.12837263, 0.32387041, 0.40538279, 0.56577991, 0.83225191,
#         1.85164705]),
#  array([0.34951565, 1.04696048, 1.68348256]),
#  array([0.52558786, 0.55127124]),
#  array([0.7238521 , 1.46274532, 1.63767943, 1.90825963]),
#  array([0.20387932, 0.40992709, 0.42734604]),
#  array([0.7303509 , 0.76739702, 1.29812013]),
#  array([0.58168526, 0.69182265, 0.93553492, 1.04402799, 1.04925577]),
#  array([], dtype=float64),
#  array([0.05224096, 0.39872352, 0.96946593, 1.65555885, 1.99753264]),
#  array([1.17018952]),
#  array([0.50905119, 0.76019059, 0.80453113, 0.95338772, 0.96459026,
#         1.32583471, 1.84021975]),
#  array([0.94344203, 1.21289288, 1.2795604 , 1.5943878 , 1.78059243]),
#  array([0.62367968, 0.76150001, 0.78036342, 0.84538524, 1.74243295]),
#  array([0.63015618, 0.87826631, 1.13186846, 1.78624527]),
#  array([0.64580166, 0.71552202, 1.05856385, 1.11820584, 1.73696187]),
#  array([0.03875724, 1.08993551, 1.32151692]),
#  array([1.5099391 , 1.80643197]),
#  array([0.69028182, 1.10120454, 1.3968299 ]),
#  array([0.63233311, 0.908208  , 1.1317513 , 1.72684639]),
#  array([1.27929681, 1.38191718]),
#  array([0.81432181, 1.07893766, 1.70601552]),
#  array([0.53279605, 1.18116194]),
#  array([0.50528206, 0.72049612, 0.89931636, 1.070086  , 1.30495524,
#         1.33318532, 1.8901931 ]),
#  array([0.67450874, 0.70167041, 1.0942752 ]),
#  array([0.29489296, 0.4088271 , 0.60735928, 0.77443693, 1.08145737,
#         1.28655044, 1.50900847, 1.63485976]),
#  array([0.30698264, 0.3942787 , 0.42976998, 0.46983841, 0.831443  ,
#         0.93166086, 1.10630266, 1.32632249, 1.79958726]),
#  array([0.02092465, 0.63065089, 0.90556068, 1.29946653, 1.36290992]),
#  array([0.75293785, 0.93668703, 1.45538662]),
#  array([0.41316153, 0.43970994, 0.94563293, 1.42902077]),
#  array([], dtype=float64),
#  array([0.89992257, 0.90498778, 0.92065215, 0.94437705, 1.44611567,
#         1.63073566, 1.8258199 ]),
#  array([1.1900316]),
#  array([0.40222053, 0.92239149, 1.9380443 ]),
#  array([1.05721862, 1.38782493]),
#  array([0.96329847, 1.24204947, 1.42265656, 1.65535797]),
#  array([1.0361598 , 1.74196547, 1.77612025]),
#  array([0.18937091, 0.44717368, 1.23681834]),
#  array([0.55418898, 0.96781783, 1.89238861, 1.95563954]),
#  array([0.51094115, 1.18894946, 1.54031851, 1.61175672]),
#  array([0.84829713, 1.99595249]),
#  array([0.05760999, 1.00853745, 1.38891765]),
#  array([0.66686367, 1.31103666, 1.33545718]),
#  array([0.72742862, 0.86449135, 1.61862912, 1.99607166]),
#  array([0.28800434, 0.7039425 , 1.28198535, 1.38012323, 1.69658633]),
#  array([0.27190563, 0.37067767, 0.62962584, 1.94242813]),
#  array([0.53870604, 0.94924034, 1.47795863]),
#  array([0.19964069, 0.91799912]),
#  array([0.25375053, 0.41090499, 0.55810344, 1.25163643, 1.82489092]),
#  array([0.26324329, 0.3409422 , 1.23199736, 1.50691074, 1.65518016]),
#  array([0.10097304, 0.61908128, 0.76492955, 0.81457708, 0.94159171,
#         1.10625269, 1.51920407]),
#  array([1.09992094]),
#  array([0.64869435, 1.02184458, 1.93614258]),
#  array([0.62080001, 0.95941218, 1.41288515]),
#  array([0.3594394, 0.9307315]),
#  array([0.35292609, 1.59594257]),
#  array([0.69112206, 0.74769193, 0.91451503, 1.30198482, 1.49229686,
#         1.96199266]),
#  array([0.31218136, 0.38027355, 0.46116241, 0.6940075 , 0.70572426,
#         0.80735578]),
#  array([1.49487747, 1.97309807]),
#  array([0.59808204, 1.05452951, 1.44181752, 1.45441414]),
#  array([0.83778109]),
#  array([0.19842373, 0.56967263, 0.76651852, 1.14844556]),
#  array([0.53424795, 1.09465488, 1.26943563, 1.40425162]),
#  array([0.08503685, 0.46603745, 0.85897083, 1.00539411, 1.24058457,
#         1.28838485, 1.74351579, 1.92954177]),
#  array([0.37041941, 0.64197673, 0.88308581, 1.79651969]),
#  array([0.17060763, 1.22276615, 1.90463751]),
#  array([0.50782768, 0.63207983, 0.93235356]),
#  array([0.09968104, 0.98918403, 1.34997371, 1.49022308]),
#  array([0.48990625, 0.74612282, 1.1553177 , 1.18121433, 1.73214115]),
#  array([0.36259534, 0.79947831, 1.08821764, 1.52575818, 1.88099828]),
#  array([0.2515297 , 0.63891057, 0.69072602]),
#  array([], dtype=float64),
#  array([0.42807799, 0.84424233, 1.11229382, 1.19549842, 1.48437717,
#         1.52612111]),
#  array([0.00221137, 0.33828293, 1.3375181 ]),
#  array([0.51973671, 0.65273321, 0.75585451, 1.20455866, 1.42126777,
#         1.50379505]),
#  array([0.67416418, 0.85995702, 1.17114205]),
#  array([0.28386664, 0.73518114, 1.90355803]),
#  array([0.39841774, 0.66090158, 1.03768757, 1.114005  , 1.12572202]),
#  array([0.63398704, 0.70067119, 1.2384376 , 1.4282602 , 1.92467336]),
#  array([], dtype=float64),
#  array([0.63164096, 1.79857713]),
#  array([0.46939804, 1.75735277]),
#  array([0.68893974, 1.24335678, 1.75908654, 1.77339427, 1.94313971]),
#  array([0.09210353, 0.44067153]),
#  array([0.66597521, 1.15625217, 1.54042441, 1.6188379 , 1.64356541]),
#  array([0.68072092]),
#  array([0.59011411, 0.65029303, 0.76244908]),
#  array([1.21581051, 1.73906457, 1.76984296]),
#  array([0.01505048]),
#  array([0.86079833, 1.03156042, 1.5764814 ]),
#  array([], dtype=float64),
#  array([0.55155104, 0.87547987, 0.98859652, 1.21572512, 1.41672727,
#         1.65234   ]),
#  array([0.12265486, 0.41834874]),
#  array([0.61097043, 1.0163987 , 1.88844567]),
#  array([0.37604296, 0.57509466, 0.58694153, 1.01748248, 1.02020854,
#         1.13104561, 1.14509802, 1.94371136]),
#  array([0.21561403]),
#  array([1.11184737, 1.32774598]),
#  array([0.72716324, 0.91681163, 1.00109032, 1.03996056, 1.36634743]),
#  array([0.7451667 , 0.94561274, 1.90646447]),
#  array([0.83602109, 0.91188337, 1.38228935, 1.40575444, 1.78990223]),
#  array([0.67778383]),
#  array([1.48739836, 1.52879013, 1.81061052]),
#  array([0.07819691, 0.50074952, 0.82051456, 1.5118955 ]),
#  array([0.63380156, 1.43507912]),
#  array([0.39671548, 0.42757514, 0.59913768, 0.73147076, 0.79318733,
#         0.93799142]),
#  array([0.32883751, 1.10584515]),
#  array([0.25999423, 0.9274892 , 1.07287562, 1.15677106]),
#  array([0.68690924, 0.80169073]),
#  array([0.37375894, 1.29712445]),
#  array([0.89176213, 1.26865444, 1.53979748]),
#  array([0.72324083, 1.23959175, 1.72525298]),
#  array([1.11919896, 1.70404219]),
#  array([1.52448336, 1.81939265]),
#  array([0.66703429, 0.86832278, 1.17510503, 1.89531027]),
#  array([0.60168596, 0.77710497, 1.33506734, 1.74004666, 1.85972195,
#         1.91617118]),
#  array([0.48898009, 0.61886217, 1.10166656, 1.87568768]),
#  array([0.88552568, 0.99132793, 1.0780485 , 1.23563293]),
#  array([0.11083663, 0.64120738, 0.76935978, 0.94083313]),
#  array([0.39639728, 0.73325236, 1.04780308]),
#  array([0.13501927, 0.85980167, 1.16408616, 1.89726575]),
#  array([0.36650872, 1.0895066 , 1.25155888]),
#  array([0.26114542, 0.38635222, 0.53712907, 1.33100669, 1.54940974]),
#  array([0.19647175, 0.30826733, 0.64403608, 0.98493872]),
#  array([0.24127159, 0.54186485, 1.15314146, 1.55965571]),
#  array([0.0241577 , 0.62318863, 0.89398499, 0.98680753]),
#  array([0.47086894, 1.16553886, 1.48987167, 1.73294971, 1.99458616]),
#  array([0.19540996, 1.03303639]),
#  array([0.01382709, 0.42049407, 1.10098296]),
#  array([0.16722356, 0.2003869 , 1.41218714]),
#  array([0.05722013, 0.56789698, 0.99357904, 1.2075123 ]),
#  array([1.18125312, 1.85242306]),
#  array([0.92608068, 1.03330799, 1.4771204 , 1.99475994]),
#  array([0.40066322, 0.47991597, 0.75410981, 0.93663033, 1.20308567]),
#  array([0.15614863, 0.32974206, 1.20923452]),
#  array([0.46854198, 0.66596741, 0.70475544, 0.72125234, 0.91968555,
#         1.26658031]),
#  array([0.76147406, 1.37796617, 1.8555371 ]),
#  array([0.03948989, 0.31140173, 0.39983351, 0.42975091, 0.51480901,
#         1.27640398]),
#  array([0.21514014, 0.26029805, 0.42956404, 0.5590634 , 1.18593262,
#         1.64553443]),
#  array([0.63167617, 1.94867216]),
#  array([0.61379085, 1.29591542]),
#  array([0.67770372]),
#  array([0.3370499 , 0.69631172, 1.47718012]),
#  array([0.72464769]),
#  array([0.11819503, 0.95377039, 1.098292  , 1.2073045 , 1.35107411,
#         1.62747482]),
#  array([0.97822665, 0.98115827, 1.59415286, 1.86455028, 1.9417765 ]),
#  array([0.25143112, 0.26172603, 0.33212491, 0.45099415, 0.50712532,
#         1.60669583, 1.71383903]),
#  array([0.51250633, 0.52862039]),
#  array([], dtype=float64),
#  array([0.59554021, 0.95885234, 1.39068   , 1.57283302]),
#  array([0.42561093]),
#  array([0.62596469, 0.76605541, 0.96136496, 1.22727086, 1.40383251,
#         1.63264685, 1.6511482 , 1.735676  ]),
#  array([0.57204473, 0.60080805]),
#  array([1.01643451, 1.19786847]),
#  array([1.11998651, 1.98320245]),
#  array([0.09889613, 0.95046159, 1.46265   ]),
#  array([0.41356864, 1.58904819]),
#  array([0.38370233, 1.20610648, 1.96604917]),
#  array([0.72410998, 0.89495339, 1.01921549]),
#  array([0.42333128, 1.24328749]),
#  array([1.12750271]),
#  array([0.85866263]),
#  array([0.64466273, 1.2346272 , 1.74574331, 1.80087333]),
#  array([0.67118158, 1.53129971]),
#  array([0.09682411, 0.5767622 , 1.09091468, 1.60973968]),
#  array([0.07174142, 0.5036166 , 0.63765345, 0.71526099, 0.81845062,
#         1.06787039, 1.08660549, 1.28777985, 1.46909778]),
#  array([0.18986404]),
#  array([0.40950815, 0.62740074, 0.96059557]),
#  array([0.78247511]),
#  array([0.49261902, 0.59180971, 0.59549416, 0.85509956, 1.00041038,
#         1.36975471]),
#  array([1.15895542, 1.35721674, 1.39384602, 1.77253108]),
#  array([0.36406328, 0.71340461]),
#  array([1.39449838, 1.79450249, 1.95265177]),
#  array([0.25183617, 0.3095068 , 0.32172073, 0.87611678, 0.94958551,
#         1.01298705, 1.25115831, 1.66128744]),
#  array([0.48265691, 0.56460188, 0.98649069, 1.05783352, 1.22261331]),
#  array([0.35264715, 1.11785261, 1.87519141]),
#  array([0.2405113 , 0.2844709 , 0.50306238]),
#  array([0.76503555, 1.14696118]),
#  array([0.66162069, 1.00776395, 1.25967662, 1.69242661, 1.70513835,
#         1.81375237]),
#  array([0.50621088, 1.25924831, 1.40590276]),
#  array([1.32386381, 1.36572389, 1.74137798, 1.9036538 ]),
#  array([0.22000595, 0.40860443, 0.78037249, 1.14572645, 1.8594014 ,
#         1.87926794]),
#  array([0.19986242, 0.55966692, 0.87367843, 1.62411799]),
#  array([0.50326481, 1.10213848, 1.22831958, 1.29836954, 1.93389413]),
#  array([0.01312103, 0.41514668, 0.46596694]),
#  array([0.40604427, 1.21656715]),
#  array([0.40257914, 0.43458753, 1.57186444, 1.6819977 ]),
#  array([0.66967875, 0.93494251, 1.07438293, 1.57471458, 1.89880781]),
#  array([0.24369382, 0.62715357, 0.73974669]),
#  array([0.31125841, 0.35619352, 0.78850676, 0.843748  , 1.6798488 ]),
#  array([0.14042555, 0.42876948, 1.15267486]),
#  array([0.56264156, 0.75853243, 0.95885586, 1.60916612, 1.79762417,
#         1.96705616]),
#  array([0.60929606]),
#  array([1.06469425, 1.48497818, 1.98174397]),
#  array([0.60933243, 0.70948633, 0.99771788, 1.34285925, 1.54797997]),
#  array([0.07439627, 0.11103915, 1.41230011, 1.46950586]),
#  array([0.92740899, 1.01217706]),
#  array([0.28129267, 0.53765937, 1.20112118]),
#  array([0.08058298, 0.96921476, 1.35130698]),
#  array([0.2178081 , 0.37321352, 1.23323236, 1.46115924, 1.66377512]),
#  array([0.20559927, 0.62705581, 0.87913864, 1.22190053, 1.25953268,
#         1.41402656]),
#  array([0.67129195, 0.69628064]),
#  array([0.13745608, 0.18967765, 0.78297331, 1.04021473, 1.37486109,
#         1.37993846]),
#  array([0.06147676, 0.30415742, 0.64576663, 0.9045774 , 1.05464909,
#         1.59000049, 1.71340358]),
#  array([0.52126446, 0.98502955, 1.0917824 , 1.53156845]),
#  array([0.26817196, 0.65550023]),
#  array([0.49422571, 0.50941937, 0.665121  , 1.05693703]),
#  array([0.53040592, 0.70020295]),
#  array([1.13323063, 1.13784842]),
#  array([0.63822423, 1.0108413 , 1.06643264, 1.19054532]),
#  array([0.54971282, 0.92388662, 1.02085601, 1.64200639]),
#  array([0.04915121, 0.08990687]),
#  array([0.17335027, 0.52414065, 0.52896889, 0.5922321 , 1.138137  ,
#         1.40552795, 1.48088475, 1.52259871]),
#  array([0.55042207, 1.70067422, 1.89987948]),
#  array([0.15023942]),
#  array([0.00667812, 0.18505802, 1.04647078, 1.37548003]),
#  array([0.49521708, 0.53437568, 1.20027701, 1.46831943]),
#  array([1.24467831]),
#  array([0.18971702, 0.51604751]),
#  array([0.44854901, 0.60152118, 0.68146082, 0.85760531, 1.80257333]),
#  array([0.3769334 , 0.65258373, 1.41761719, 1.46315283]),
#  array([0.10362544, 0.85110024, 1.03665638, 1.28810241]),
#  array([1.19616669, 1.33838154, 1.72604487, 1.82350871]),
#  array([0.31338007, 1.23923318, 1.96508453]),
#  array([0.41865787, 0.73065993, 1.26360122, 1.55591407]),
#  array([0.61836365, 1.04494478, 1.40226439]),
#  array([0.7185691 , 0.92070762, 1.86764547]),
#  array([0.02166549, 0.69338562, 1.0809849 , 1.42188829]),
#  array([0.49252563, 0.98395797, 1.02391715, 1.34193215, 1.71897579]),
#  ...]

# %%
ts = np.linspace(0.0, 1, 101)

means = np.zeros(101)

for j, t in enumerate(ts):
    for i in range(0, n):
        means[j] += np.sum(S[i] <= t)

means = means / n

y = -(ts **3)/3 + (ts**2) + ts

plt.plot(ts, means)
plt.plot(ts, y)

# %% [markdown]
# ## Order Statistic Method
#
# Implement the order statistic method, following the below scaffold for the intensity function:
# $\lambda(t)=42t*exp(-t^2)$ for $0<=t<=6$

# %%
import numpy as np
from scipy.stats import poisson, uniform

#Compute the expected number of arrivals between 0 and T
#Your function should return a float

def Ex_arrivals(T):
    return 21 * (1- np.exp(-T**2))

#simulate the actual number of arrivals between 0 and T
#hint: you can need to call Ex_arrivals(T) function you 
#constructed in the last step
def N_arrivals(T):
    L = Ex_arrivals(T)
    return poisson.rvs(L)

N_arrivals(T = 6)

#Calculate the inverse cdf for the unordered arrival times

def inv_cdf(u, T):
    term1 = 1 - np.exp(-T**2)
    return np.sqrt(- np.log(1 - u * term1))

# Combine all the previous functions to simulate the process up to time T

np.random.seed(1996)
def Simulate(T):
    N = N_arrivals(T)
    X = np.zeros(N)
    for i in range(N):
        u = uniform.rvs()
        X[i] = inv_cdf(u, T)
    return  np.sort(X)

result_simulation = Simulate(T = 6)
result_simulation
# Out:
# array([0.07162409, 0.250669  , 0.26133756, 0.31571496, 0.40889667,
#        0.50773498, 0.50932239, 0.53008839, 0.60658651, 0.62853664,
#        0.66058952, 0.76430313, 0.88371247, 0.97831058, 1.06344273,
#        1.10980383, 1.18246613, 1.3000786 , 1.30693752, 1.53319418,
#        1.81310792, 1.85130138, 1.96527166])

# %% [markdown]
# ## Inversion Method
#
# Implement the inversion method given generic mean function Λ(t).
#
# Generate some paths using Λ(t)=1−exp(−t^2) from 0≤t≤10.
#
# Generate 10,000 paths from a nonhomogeneous poisson process with mean function Λ(t)=1−exp(−t^2) from 0≤t≤10.
#
# Over the grid t = [.01, .02, ..., 1.0], plot mean number of events that have occured by that time over the set of paths. Compare to the theoretical mean function.

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import poisson, uniform
from scipy.optimize import root_scalar

def poisson_process(lmbda, T):
    N = poisson.rvs(lmbda*T)
    S = uniform.rvs(size=N) * T
    return np.sort(S)

def Lmbda(t):
    return 1 + np.exp(-t**2)

## implement the inverse method here

def inv_method(Lmbda, T):
    LmbdaT = Lmbda(T)
    s = poisson_process(1, LmbdaT)
    ts = np.zeros(len(s))
    for i, t in enumerate(s):
        L = lambda x: Lmbda(x) - t
        ts[i] = root_scalar(L, bracket=[0,T], method='bisect').root
    return ts

n = 10_000
T = 10

S = []
for i in range(n):
    S.append(inv_method(Lmbda, T))

ts = np.linspace(0.0, 1, 101)

means = np.zeros(101)

for j, t in enumerate(ts):
    for i in range(0, n):
        means[j] += np.sum(S[i] <= t)

means = means / n

y = Lmbda(ts)

plt.plot(ts, means)
plt.plot(ts, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 30
#      28 S = []
#      29 for i in range(n):
# ---> 30     S.append(inv_method(Lmbda, T))
#      32 ts = np.linspace(0.0, 1, 101)
#      34 means = np.zeros(101)
#
# Cell In[27], line 22, in inv_method(Lmbda, T)
#      20 for i, t in enumerate(s):
#      21     L = lambda x: Lmbda(x) - t
# ---> 22     ts[i] = root_scalar(L, bracket=[0,T], method='bisect').root
#      23 return ts
#
# File c:\Users\Silvia\anaconda3\lib\site-packages\scipy\optimize\_root_scalar.py:275, in root_scalar(f, args, method, bracket, fprime, fprime2, x0, x1, xtol, rtol, maxiter, options)
#     272         raise ValueError('Bracket needed for %s' % method)
#     274     a, b = bracket[:2]
# --> 275     r, sol = methodc(f, a, b, args=args, **kwargs)
#     276 elif meth in ['secant']:
#     277     if x0 is None:
#
# File c:\Users\Silvia\anaconda3\lib\site-packages\scipy\optimize\_zeros_py.py:557, in bisect(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     555 if rtol < _rtol:
#     556     raise ValueError("rtol too small (%g < %g)" % (rtol, _rtol))
# --> 557 r = _zeros._bisect(f, a, b, xtol, rtol, maxiter, args, full_output, disp)
#     558 return results_c(full_output, r)
#
# ValueError: f(a) and f(b) must have different signs
